# %%
import pandas as pd

# %%
df = pd.read_csv(r'./channel_rbc_news_posts.csv')
df.shape
# Out:
# (4847, 6)

# %%
df = df[~df['content'].isna()]

# %%
df.sample(5)
# Out:
#       message_dt  message_id channel_id  \
# 5616  2025-06-13      120709   rbc_news
# 6477  2025-09-15      130698   rbc_news
# 656   2025-11-18      136043   rbc_news
# 3545  2025-08-10      126937   rbc_news
# 2013  2025-09-24      131587   rbc_news
#
#                                                 content     views  \
# 5616  ◻️◻️◻️ Иранское телевидение публикует видео ле...  155016.0
# 6477  У руководства Украины есть возможности для тог...  126327.0
# 656   ◻️◻️◻️ Владимир Путин в режиме видеоконференци...   99246.0
# 3545  В аэропорту Ухты введены временные ограничения...  136546.0
# 2013  Пакистанские налоговые органы начали изучать с...  121525.0
#
#      original_author
# 5616             NaN
# 6477             NaN
# 656              NaN
# 3545             NaN
# 2013             NaN

# %%
df.to_csv(r'./channel_rbc_news_posts.csv', index=False)
